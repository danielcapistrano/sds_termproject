# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
p = 0.001  # 0.1% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         "US_Accidents_March23.csv",
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p
)
df.describe()
# Out:
#           Severity    Start_Lat    Start_Lng      End_Lat      End_Lng  \
# count  7714.000000  7714.000000  7714.000000  4350.000000  4350.000000
# mean      2.207545    36.086394   -95.034303    36.176171   -96.018236
# std       0.482377     5.007461    17.400393     5.178213    18.051929
# min       1.000000    24.713240  -124.228830    24.824711  -124.228442
# 25%       2.000000    33.392496  -117.312153    33.494965  -117.758907
# 50%       2.000000    35.604980   -87.937685    36.070605   -88.227325
# 75%       2.000000    39.981489   -80.595763    40.092337   -80.334364
# max       4.000000    48.964092   -70.267100    48.964110   -70.273660
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# count   7714.000000     7566.000000    5699.000000  7552.000000   7592.000000
# mean       0.557459       62.179870      58.945499    64.578522     29.544451
# std        1.579272       18.767339      22.123809    22.849538      1.007502
# ...

# %%
# https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents

# %%
df
# Out:
#              ID   Source  Severity           Start_Time             End_Time  \
# 0         A-511  Source2         2  2016-03-07 09:02:27  2016-03-07 09:32:27
# 1         A-739  Source2         2  2016-06-21 11:02:59  2016-06-21 11:32:59
# 2        A-3829  Source2         2  2016-07-22 13:56:17  2016-07-22 14:26:17
# 3        A-4083  Source2         3  2016-07-25 09:17:50  2016-07-25 09:47:50
# 4        A-4997  Source2         2  2016-08-01 11:41:23  2016-08-01 12:26:23
# ...         ...      ...       ...                  ...                  ...
# 7709  A-7772329  Source1         3  2019-08-12 02:44:25  2019-08-12 03:13:24
# 7710  A-7775364  Source1         2  2019-08-19 09:21:07  2019-08-19 09:49:13
# 7711  A-7776605  Source1         2  2019-08-21 10:30:34  2019-08-21 14:30:34
# 7712  A-7777013  Source1         4  2019-08-23 00:06:16  2019-08-23 00:34:00
# 7713  A-7777639  Source1         2  2019-08-23 13:54:42  2019-08-23 14:21:56
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                          0
# Source                      0
# Severity                    0
# Start_Time                  0
# End_Time                    0
# Start_Lat                   0
# Start_Lng                   0
# End_Lat                  3364
# End_Lng                  3364
# Distance(mi)                0
# Description                 0
# Street                      6
# City                        1
# County                      0
# State                       0
# Zipcode                     4
# Country                     0
# Timezone                    9
# Airport_Code               21
# Weather_Timestamp         108
# Temperature(F)            148
# Wind_Chill(F)            2015
# Humidity(%)               162
# Pressure(in)              122
# Visibility(mi)            157
# Wind_Direction            152
# Wind_Speed(mph)           540
# Precipitation(in)        2226
# Weather_Condition         156
# Amenity                     0
# Bump                        0
# ...

# %%
print(df.corr())
# Out:
#                    Severity  Start_Lat  Start_Lng   End_Lat   End_Lng  \
# Severity           1.000000   0.049403   0.042454  0.071406  0.072404
# Start_Lat          0.049403   1.000000  -0.070726  0.999995 -0.120259
# Start_Lng          0.042454  -0.070726   1.000000 -0.120320  0.999999
# End_Lat            0.071406   0.999995  -0.120320  1.000000 -0.120340
# End_Lng            0.072404  -0.120259   0.999999 -0.120340  1.000000
# Distance(mi)       0.044466   0.069250   0.020557  0.072984  0.004780
# Temperature(F)     0.005212  -0.427936  -0.003128 -0.451143  0.024490
# Wind_Chill(F)     -0.042589  -0.466618  -0.031037 -0.472063  0.007638
# Humidity(%)        0.017229   0.009802   0.183848  0.016494  0.177598
# Pressure(in)       0.050578  -0.191030   0.187990 -0.235349  0.222911
# Visibility(mi)     0.000901  -0.085629  -0.010676 -0.105636  0.006912
# Wind_Speed(mph)    0.045968   0.032922   0.099667  0.008317  0.107853
# ...

# %%
f,ax = plt.subplots(figsize=(10, 8))
heatmap = sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
heatmap.set_title('Correlation heatmap', fontdict={'fontsize':20}, pad=16)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/yk/nhvk3n4117g7njndctwmlq180000gn/T/ipykernel_15036/3310398894.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
# Comment
# - I don't see any particular strong correlation between severity and any one column
# - Potentially combination of column would be good indicators though
# - time is not selected in this heatmap. I think we need to group the data before plotting with time

# at a glance. I think it is a workable dataset and we can come up with hypothesis like
# - Severity can be predicted by variables
