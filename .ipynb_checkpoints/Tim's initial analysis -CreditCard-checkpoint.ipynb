# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
p = 0.1  # 10% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         "CreditCard.csv",
         header=0, 
         skiprows=lambda i: i>0 and random.random() > p
)
df.describe()
# Out:
#          fraud_bool        income  name_email_similarity  \
# count  99751.000000  99751.000000           99751.000000
# mean       0.010306      0.564018               0.493129
# std        0.100993      0.290366               0.289201
# min        0.000000      0.100000               0.000019
# 25%        0.000000      0.300000               0.224885
# 50%        0.000000      0.600000               0.491255
# 75%        0.000000      0.800000               0.755327
# max        1.000000      0.900000               0.999996
#
#        prev_address_months_count  current_address_months_count  customer_age  \
# count               99751.000000                  99751.000000  99751.000000
# mean                   17.029513                     85.708765     33.664825
# std                    44.469862                     87.911366     11.986270
# min                    -1.000000                     -1.000000     10.000000
# ...

# %%
# https://www.kaggle.com/datasets/sgpjesus/bank-account-fraud-dataset-neurips-2022

# %%
df
# Out:
#        fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0               0     0.3               0.986506                         -1
# 1               0     0.2               0.773085                         22
# 2               0     0.1               0.767432                         -1
# 3               0     0.5               0.674870                         -1
# 4               0     0.7               0.450057                         -1
# ...           ...     ...                    ...                        ...
# 99746           0     0.8               0.988424                         -1
# 99747           0     0.7               0.129088                         -1
# 99748           0     0.9               0.432945                         55
# 99749           0     0.8               0.140891                         -1
# 99750           0     0.6               0.993391                         -1
#
# ...

# %%
df.isnull().sum()
# Out:
# fraud_bool                          0
# income                              0
# name_email_similarity               0
# prev_address_months_count           0
# current_address_months_count        0
# customer_age                        0
# days_since_request                  0
# intended_balcon_amount              0
# payment_type                        0
# zip_count_4w                        0
# velocity_6h                         0
# velocity_24h                        0
# velocity_4w                         0
# bank_branch_count_8w                0
# date_of_birth_distinct_emails_4w    0
# employment_status                   0
# credit_risk_score                   0
# email_is_free                       0
# housing_status                      0
# phone_home_valid                    0
# phone_mobile_valid                  0
# bank_months_count                   0
# has_other_cards                     0
# proposed_credit_limit               0
# foreign_request                     0
# ...

# %%
print(df.corr())
# Out:
# /var/folders/yk/nhvk3n4117g7njndctwmlq180000gn/T/ipykernel_15480/4212406737.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.corr())
#                                   fraud_bool    income  name_email_similarity  \
# fraud_bool                          1.000000  0.044575              -0.037321
# income                              0.044575  1.000000              -0.037079
# name_email_similarity              -0.037321 -0.037079               1.000000
# prev_address_months_count          -0.024403  0.021197              -0.020720
# current_address_months_count        0.033745 -0.040130               0.054619
# customer_age                        0.064286  0.126439              -0.041901
# days_since_request                  0.000295 -0.013365              -0.008032
# ...

# %%
f,ax = plt.subplots(figsize=(10, 8))
heatmap = sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
heatmap.set_title('Correlation heatmap', fontdict={'fontsize':20}, pad=16)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/yk/nhvk3n4117g7njndctwmlq180000gn/T/ipykernel_15480/3310398894.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
# Comment
# - I don't see any particular one strong correlation between severity and any one column
# - Potentially combination of column would be good indicators though

# at a glance. I think it is a workable dataset and we can come up with hypothesis
