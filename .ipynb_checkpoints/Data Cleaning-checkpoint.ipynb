# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
p = 0.1  # 10% of the lines
# keep the header, then take only 1% of lines
# if random from [0,1] interval is greater than 0.01 the row will be skipped
df = pd.read_csv(
         "CreditCard.csv",
         header=0,
         skiprows=lambda i: i>0 and random.random() > p
)
df.describe()
# Out:
#          fraud_bool        income  name_email_similarity  \
# count  99678.000000  99678.000000           99678.000000
# mean       0.011246      0.562862               0.494620
# std        0.105451      0.290044               0.289068
# min        0.000000      0.100000               0.000010
# 25%        0.000000      0.300000               0.226427
# 50%        0.000000      0.600000               0.493391
# 75%        0.000000      0.800000               0.756045
# max        1.000000      0.900000               0.999999
#
#        prev_address_months_count  current_address_months_count  customer_age  \
# count               99678.000000                  99678.000000  99678.000000
# mean                   16.524358                     86.737655     33.655872
# std                    43.414090                     88.588750     12.069431
# min                    -1.000000                     -1.000000     10.000000
# ...

# %%
# https://www.kaggle.com/datasets/sgpjesus/bank-account-fraud-dataset-neurips-2022

# %%
df
# Out:
#        fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0               0     0.2               0.773085                         22
# 1               0     0.1               0.767432                         -1
# 2               0     0.8               0.122370                         -1
# 3               0     0.5               0.674870                         -1
# 4               0     0.7               0.450057                         -1
# ...           ...     ...                    ...                        ...
# 99673           0     0.7               0.641901                         -1
# 99674           0     0.9               0.945543                         -1
# 99675           0     0.4               0.785117                         -1
# 99676           0     0.1               0.343666                         27
# 99677           0     0.8               0.532661                         12
#
# ...

# %%
df.dtypes
# Out:
# fraud_bool                            int64
# income                              float64
# name_email_similarity               float64
# prev_address_months_count             int64
# current_address_months_count          int64
# customer_age                          int64
# days_since_request                  float64
# intended_balcon_amount              float64
# payment_type                         object
# zip_count_4w                          int64
# velocity_6h                         float64
# velocity_24h                        float64
# velocity_4w                         float64
# bank_branch_count_8w                  int64
# date_of_birth_distinct_emails_4w      int64
# employment_status                    object
# credit_risk_score                     int64
# email_is_free                         int64
# housing_status                       object
# phone_home_valid                      int64
# phone_mobile_valid                    int64
# ...

# %%
df.isnull().sum()
# Out:
# fraud_bool                          0
# income                              0
# name_email_similarity               0
# prev_address_months_count           0
# current_address_months_count        0
# customer_age                        0
# days_since_request                  0
# intended_balcon_amount              0
# payment_type                        0
# zip_count_4w                        0
# velocity_6h                         0
# velocity_24h                        0
# velocity_4w                         0
# bank_branch_count_8w                0
# date_of_birth_distinct_emails_4w    0
# employment_status                   0
# credit_risk_score                   0
# email_is_free                       0
# housing_status                      0
# phone_home_valid                    0
# phone_mobile_valid                  0
# bank_months_count                   0
# has_other_cards                     0
# proposed_credit_limit               0
# foreign_request                     0
# ...

# %%
import pandas as pd

# Separate majority and minority classes
majority_class = df[df['fraud_bool'] == 0]
minority_class = df[df['fraud_bool'] == 1]

# Determine the number of instances in the classes
majority_count = len(majority_class)
minority_count = len(minority_class)

print(f'majority count: {majority_count}')
print(f'minority count: {minority_count}')

print(f'minor:major ration: {minority_count/majority_count}')
# Out:
# majority count: 98557
# minority count: 1121
# minor:major ration: 0.011374128676806315

# %%
# Undersample majority class to match minority class
undersampled_majority = majority_class.sample(n=minority_count)

# Combine minority and undersampled majority classes
balanced_df = pd.concat([undersampled_majority, minority_class])

# Shuffle the balanced dataset to ensure randomness
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Optional: Check the class distribution after undersampling
print(balanced_df['fraud_bool'].value_counts())
# Out:
# 0    1121
# 1    1121
# Name: fraud_bool, dtype: int64

# %%
balanced_df
# Out:
#       fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0              0     0.5               0.572896                          8
# 1              0     0.7               0.206570                         -1
# 2              1     0.7               0.108923                         -1
# 3              0     0.9               0.023210                         -1
# 4              0     0.1               0.145475                         28
# ...          ...     ...                    ...                        ...
# 2237           1     0.9               0.811633                         66
# 2238           0     0.7               0.768611                         -1
# 2239           1     0.9               0.637379                         -1
# 2240           1     0.1               0.548144                         -1
# 2241           0     0.3               0.653027                         -1
#
# ...
